# %%
import numpy as np
import matplotlib.pyplot as plt
import numba
from time import time
# %matplotlib inline

# %%
def euler(volt_func, volt_init, n_func, c_func, n_init, c_init, current_funcs, t_range, dt):

    t = np.arange(t_range[0], t_range[1]+dt, dt)
    n_vector = np.empty(len(t))
    current_vector = np.empty([len(current_funcs),len(t)])
    c_vector = n_vector.copy()
    
    volt_vector = np.zeros(len(t))
    volt_vector[0] = volt_init
    #pdb.set_trace()
    n_vector[0] = n_init
    c_vector[0] = c_init
    
    n_vector, c_vector, current_vector, volt_vector = euler_integrate_jit\
    (volt_vector,volt_func,n_vector,c_vector,n_func,c_func,current_vector,current_funcs,dt,t)               
        
    return t, n_vector, c_vector, current_vector, volt_vector

@numba.jit
def euler_integrate_jit(volt_vector,volt_func,n_vector,c_vector,n_func,c_func,current_vector,current_funcs,dt,t):
    for i in range(len(t)-1):
        tempVoltage = volt_vector[i]
        
        #compute c and n at current time step
        n_vector[i+1] = n_vector[i] + dt * n_func(n_vector[i],tempVoltage,t[i])
        c_vector[i+1] = c_vector[i] + dt * c_func(c_vector[i],tempVoltage,t[i])
        
        # compute I_Ca at current time step
        current_vector[0,i] = current_funcs[0](tempVoltage)
        
        # compute I_K_HH at current time step
        current_vector[1,i] = current_funcs[1](n_vector[i],tempVoltage)
        
        # compute I_K_Ca at current time step
        current_vector[2,i] = current_funcs[2](c_vector[i],tempVoltage)
        
        # compute I_L at current time step
        current_vector[3,i] = current_funcs[3](tempVoltage)
        
        volt_vector[i+1] = volt_vector[i] + dt * volt_func(current_vector[0,i],current_vector[1,i],current_vector[2,i],current_vector[3,i])
    return n_vector, c_vector, current_vector, volt_vector

def n_ode(n, V, t):
    a = a_n(V)
    b = b_n(V)
    result = a * (1 - n) - b * n
    return result


def concentration_ode(c, V, t):
    f = 0.007
    k1 = 0.0275 #microM*cm^2/nC
    kc = 0.02 #ms^-1
    return f * (-k1*I_Ca(V) - c*kc)

#We changed the values accordingly
#V + V* = V - 15 for m and h
#V + V* = V - 35 for n

def a_n(V):
    V = V - 35.0
#    return (0.01* (V + 20)) / (1 - np.exp(-0.1 * (V + 20)))
#    return (0.01 * (V - 10.0))/(np.exp((V-10.0)/10.0) - 1.0)
    return ((V+55.0)/100.0)/(1.0 - np.exp(-(V + 55.0)/10.0))
def b_n(V):
    V = V - 35.0
#    return 0.125 * np.exp(-0.0125 *(V + 20))
#    return 0.125 * np.exp(V/80.0)
    return np.exp(-(V + 65.0)/80.0)/8.0

def a_m(V):
    V = V-15.0
#    return 0.1* (V + 25) /(1 - np.exp(-0.1 *(V + 25)))
#    return (0.1 * (V - 25.0)) / ((np.exp((V-25.0)/10.0)) - 1.0)
    return ((V+40.0)/10.0)/(1.0 - np.exp(-(V + 40.0)/10.0))
    
def a_h(V):
    V = V-15.0
#    return 0.07 * np.exp(-0.05 *(V + 50))
#    return 0.07 * np.exp(V/20.0)
    return 7.0*np.exp(-(V + 65.0)/20.0)/100.0

def b_m(V):
    V = V-15.0
#    return 4.0 * np.exp(-0.0556 *(V + 50))
#    return 4.0*np.exp(V/18.0)
    return 4.0*np.exp(-(V + 65.0)/18.0)

def b_h(V):
    V = V-15.0
#    return 1.0 /(1+ np.exp(-0.1 *(V+20)))
#    return (np.exp((V-30.0)/10.0)+1)**(-1)
    return 1.0/(1.0 + np.exp(-(V + 35.0)/10.0))

def m_steady(V):
    return a_m(V)/(a_m(V) + b_m(V))

def h_steady(V):
    return a_h(V)/(a_h(V) + b_h(V))


def voltage_ode (I_Ca, I_K_HH, I_K_Ca, I_L):
    C_m = 1
    return (-I_Ca - I_K_HH - I_K_Ca - I_L)/C_m

def I_K_HH(n,V):
    g_K = 5.5 #mS/cm^2
    V_K = -75 # mV
    return g_K* n**4 * (V-V_K)

def I_K_Ca(c, V):
    g_K_Ca = 0.05 #mS/cm^2
    K_d = 1 # micro mol per liter
    V_K = -75 #mV
    return c * g_K_Ca / (K_d + c) * (V - V_K)

def I_L(V):
    g_L = 0.03 #mS/cm^2
    V_L = -40 #mV
    return g_L* (V-V_L)

def I_Ca(V):
    g_Ca = 8 #mS/cm^2
    V_Ca = 100 #mV
    return g_Ca * m_steady(V)**3 * h_steady(V) * (V - V_Ca)

def tau_n (V):
    return 1/(a_n(V) + b_n(V))

# %%
#t, n_vector, c_vector, current_vector, volt_vector
# (a)
# volt_func, volt_init, act_funcs, act_func_inits, current_funcs, t_range, dt


#(volt_func, volt_init, n_func, c_func, n_init, c_init, current_funcs, t_range, dt):
volt_init = -50
n_init = 0
c_init = 0.45
dt = 0.01
time_in_seconds = 50
t_range = np.array([0,time_in_seconds*1000.0])


time1 = time()
#%timeit euler(voltage_ode, volt_init, n_ode, concentration_ode, n_init, c_init, [I_Ca, I_K_HH, I_K_Ca, I_L], t_range, dt)
t, n, c, current, volt = euler(voltage_ode, volt_init, n_ode, concentration_ode, n_init, c_init, [I_Ca, I_K_HH, I_K_Ca, I_L], t_range, dt)

time2 = time()

print time2-time1
# Out:
# 182.218399048

# %%
def compute_fr(volt,threshold):
    volt_below_thr = volt<threshold
    volt_above_thr = volt>threshold
    spike_idc = np.logical_and(volt_below_thr, np.roll(volt_above_thr,-1))
    nspikes = np.sum(spike_idc)
    return nspikes, spike_idc

nspikes, spike_idc = compute_fr(volt,-20)
print spike_idc

nspikes, spike_idc = compute_fr(volt,-20)
plt.figure()
timeWindow = np.arange(int(time_in_seconds*1000/dt))
plt.plot(spike_idc)
print nspikes
# Out:
# [False False False ..., False False False]
# 130

# %% [raw]
# a = np.zeros(len(spike_idc))
# a[spike_idc] = 1
# b = np.nonzero(a)[0]
#
# np.roll(b, )

# %%
timeWindow = np.arange(int(time_in_seconds*1000/(dt)))
plt.plot(t,volt)
plt.vlines(t[spike_idc],-50,0)
ax = plt.gca()
ax.ticklabel_format(useOffset = 0)
plt.title('Voltage')
plt.xlabel('time [s]')
plt.figure()
plt.plot(timeWindow,current[:,timeWindow].T)
plt.xlabel('time [ms]')
plt.legend(['I_Ca', 'I_K_HH', 'I_K_Ca', 'I_L'])
plt.title('Currents')
plt.figure()
plt.plot(timeWindow,n[timeWindow])
plt.xlabel('time [ms]')
plt.ylabel('Activation n')
plt.figure()
plt.plot(timeWindow,c[timeWindow])
plt.xlabel('time [ms]')
plt.ylabel('Concentration c')

# %%
spiketimes = t[spike_idc]
isi_raw = np.roll(spiketimes,-1)-spiketimes
isi_raw1 = isi_raw[0:-1]

#print isi_raw1
#a = isi_raw > 4000
#print isi_raw[a]

plt.hist(isi_raw1[isi_raw1<2000], 100)
plt.show()
plt.hist(isi_raw1[isi_raw1>2000], 50, range = [4492.85, 4493.05])
plt.show()

# %%
#def spike_pos_func(spike_time_vector, IBI_threshold):
IBIs = isi_raw1 > 2000
modulo = np.concatenate((np.array([-1]), np.nonzero(IBIs)[0]))
#print modulo

averages = np.empty(modulo[1])

for i in range(1, modulo[1]+1):
    temp = np.empty(len(modulo))
    for j in range(0, len(modulo)):
        temp[j] = isi_raw1[modulo[j]+i]
    #print temp
    averages[i-1] = np.average(temp)

#print averages
plt.plot(averages, 'k')
plt.plot(averages, 'o', color = 'red')
plt.title('ISI length across spike position')
plt.xlabel('Position of spike in burst')
plt.ylabel('Length of ISI [ms]')

# %%
Vrange = np.linspace(-100,100, 199)
#plt.plot(Vrange,tau_n(Vrange))
plt.plot(Vrange,h_steady(Vrange),'b')
plt.plot(Vrange,m_steady(Vrange),'r')
plt.legend(['h','m'])
plt.title('Steady state values of sodium channels')
plt.figure()
plt.plot(Vrange,a_m(Vrange),'b')
plt.plot(Vrange,b_m(Vrange),'r')
plt.legend(['a','b'])
plt.title('Activation values of sodium channels')

# %%
filename = "andrej.txt"
count = open(filename, "r")
row_num = 0
for i in count:
    row_num += 1
#print row_num


filein = open(filename, "r")
x = np.empty(row_num)
y = x.copy()

for i in range(0, row_num):
    text = filein.readline()
    elements = text.split()
    x[i] = elements[0]
    y[i] = elements[1]

x = x.flatten()
y = y.flatten()

x = x[np.argsort(y)]
y = y[np.argsort(y)]
    
plt.plot(x,y)

plt.plot(c, volt, color = 'red')
plt.title("Bifurcation Diagram")
plt.xlabel("c [micro Mol/Liter]")
plt.ylabel("Voltage [mV]")
plt.show()
#for i in range(0, 8):
#    frm = i * int(row_num/8)
#    to = (i+1) * int(row_num/8)
#    plt.plot(y[frm:to], x[frm:to])
#    plt.figure()

# %%
filename = "limcyc.txt"
count = open(filename, "r")
row_num = 0
for i in count:
    row_num += 1
#print row_num


filein = open(filename, "r")
c_values = np.empty(row_num)
cycles_vector = np.empty((row_num, 2))

for i in range(0, row_num):
    text = filein.readline()
    elements = text.split()
    c_values[i] = elements[0]
    cycles_vector[i, :] = elements[1:]

filename1 = "vn.txt"
filename2 = "cn.txt"
count1 = open(filename1, "r")
count2 = open(filename2, "r")
row_num1 = 0
row_num2 = 0
for i in count1:
    row_num1 += 1
for i in count2:
    row_num2 += 1

filein1 = open(filename1, "r")
filein2 = open(filename2, "r")
v_n_val = np.empty(row_num1)
c_n_val = np.empty(row_num2)

for i in range(0, row_num1):
    text = filein1.readline()
    v_n_val[i] = np.float(text)
for i in range(0, row_num2):
    text = filein2.readline()
    c_n_val[i] = np.float(text)

print v_n_val
print c_n_val
# Out:
# [-51.28386232 -50.99232857 -50.72193117 -50.46962365 -50.23298096
#  -50.01004055 -49.79919117 -49.59909338 -49.40862136 -49.22681953
#  -49.05286973 -48.88606588 -48.72579434 -48.57151833 -48.42276554
#  -48.27911814 -48.14020468 -48.00569339 -47.87528672 -47.74871676
#  -47.62574139 -47.50614106 -47.38971603 -47.27628408 -47.16567848
#  -47.05774625 -46.95234674 -46.84935025 -46.748637   -46.65009605
#  -46.55362452 -46.45912676 -46.36651374 -46.2757024  -46.18661515
#  -46.0991794  -46.0133271  -45.92899441 -45.84612135 -45.76465146
#  -45.68453156 -45.60571149 -45.52814388 -45.45178394 -45.37658929
#  -45.30251978 -45.22953732 -45.15760579 -45.08669083 -45.01675978
#  -44.94778158 -44.87972662 -44.81256666 -44.74627479 -44.68082529
#  -44.6161936  -44.55235623 -44.4892907  -44.42697551 -44.36539003
#  -44.3045145  -44.24432997 -44.18481824 -44.12596183 -44.06774395
#  -44.01014845 -43.95315982 -43.8967631  -43.8409439  -43.78568835
#  -43.73098309 -43.67681523 -43.62317235 -43.57004243 -43.5174139
#  -43.46527556 -43.4136166  -43.36242655 -43.31169531 -43.26141309
#  -43.21157042 -43.16215813 -43.11316733 -43.06458943 -43.01641607
#  -42.96863918 -42.9212509  -42.87424363 -42.82760998 -42.78134277
#  -42.73543505 -42.68988005 -42.6446712  -42.5998021  -42.55526654
#  -42.51105849 -42.46717206 -42.42360155 -42.38034138 -42.33738613]
# [ 0.1         0.10909091  0.11818182  0.12727273  0.13636364  0.14545455
#   0.15454545  0.16363636  0.17272727  0.18181818  0.19090909  0.2
#   0.20909091  0.21818182  0.22727273  0.23636364  0.24545455  0.25454545
#   0.26363636  0.27272727  0.28181818  0.29090909  0.3         0.30909091
#   0.31818182  0.32727273  0.33636364  0.34545455  0.35454545  0.36363636
#   0.37272727  0.38181818  0.39090909  0.4         0.40909091  0.41818182
#   0.42727273  0.43636364  0.44545455  0.45454545  0.46363636  0.47272727
#   0.48181818  0.49090909  0.5         0.50909091  0.51818182  0.52727273
#   0.53636364  0.54545455  0.55454545  0.56363636  0.57272727  0.58181818
#   0.59090909  0.6         0.60909091  0.61818182  0.62727273  0.63636364
#   0.64545455  0.65454545  0.66363636  0.67272727  0.68181818  0.69090909
#   0.7         0.70909091  0.71818182  0.72727273  0.73636364  0.74545455
#   0.75454545  0.76363636  0.77272727  0.78181818  0.79090909  0.8
#   0.80909091  0.81818182  0.82727273  0.83636364  0.84545455  0.85454545
#   0.86363636  0.87272727  0.88181818  0.89090909  0.9         0.90909091
#   0.91818182  0.92727273  0.93636364  0.94545455  0.95454545  0.96363636
#   0.97272727  0.98181818  0.99090909  1.        ]

# %%
plt.plot(c_n_val, v_n_val)
plt.plot(c_values, cycles_vector, color = 'yellow')
plt.plot(x,y)

plt.plot(c, volt, color = 'red')
plt.title("Bifurcation Diagram")
plt.xlabel("c [micro Mol/Liter]")
plt.ylabel("Voltage [mV]")
plt.show()
